# %% [markdown]
# # Search for the very best candidates
#
# First we collect all the data from all evolutionary experiments.

# %%
import glob
from rdkit import Chem, DataStructs

from rdkit import RDLogger  
RDLogger.DisableLog('rdApp.*')

totFitFiles=0
allCandidates=[]
unqCandidates=[]
unqCandidatesWFitness=[]
fitnesses=[]
molNames=[]
pathNames=[]
unqUIDs=[]
for fitFile in glob.glob("../run_*/*/*_FIT.sdf"):
    totFitFiles=totFitFiles+1;
    supplier = Chem.SDMolSupplier(fitFile);
    i=0
    for mol in supplier:
        i=i+1;
        mol.SetProp('Pathname',fitFile)
        allCandidates.append(mol)
        inchi = Chem.inchi.MolToInchi(mol)
        inchikey = Chem.inchi.InchiToInchiKey(inchi)
        if inchikey == '':
            print ('ERROR! Empty InChIKey.');
            break;
        if not inchikey in unqUIDs:
            unqCandidates.append(mol)
            unqUIDs.append(inchikey)
            if mol.HasProp('FITNESS'):
                unqCandidatesWFitness.append(mol)
                fitnesses.append(float(mol.GetProp('FITNESS')))
                molNames.append(mol.GetProp('_Name'))
                pathNames.append(fitFile)
    if i > 1:
        print ('ERROR! One SDF file is expected to contain only one molecule!');
        break;
    
print('Total imported FIT files:      ',totFitFiles);
print('Total candidates:              ',len(allCandidates));
print('Unique InChIKey:               ',len(unqCandidates));
print('Unique InChIKey with fitness:  ',len(unqCandidatesWFitness));

sorted(zip(fitnesses,pathNames),reverse=True)

print('Candidates listed accoring to decreasing fitness')
allNames = ""
for f,n in sorted(zip(fitnesses,pathNames),reverse=True):
    allNames = allNames + " " + n
    
print(allNames)
# Out:
# Total imported FIT files:       2523
# Total candidates:               2523
# Unique InChIKey:                1435
# Unique InChIKey with fitness:   1164
# Candidates listed accoring to decreasing fitness
#  ../run_2.0/Gen071/M00000407_FIT.sdf ../run_2.0/Gen082/M00000459_FIT.sdf ../run_2.0/Gen054/M00000317_FIT.sdf ../run_2.0/Gen049/M00000285_FIT.sdf ../run_2.0/Final/M00000167_FIT.sdf ../run_2.0/Gen061/M00000362_FIT.sdf ../run_1.1/Final/M00000299_FIT.sdf ../run_2.0/Final/M00000258_FIT.sdf ../run_1.1/Final/M00000306_FIT.sdf ../run_2.0/Gen031/M00000181_FIT.sdf ../run_1.1/Gen056/M00000369_FIT.sdf ../run_2.0/Gen090/M00000512_FIT.sdf ../run_2.0/Gen037/M00000214_FIT.sdf ../run_2.0/Gen057/M00000340_FIT.sdf ../run_2.0/Final/M00000410_FIT.sdf ../run_2.0/Gen037/M00000217_FIT.sdf ../run_2.0/Final/M00000482_FIT.sdf ../run_2.0/Gen097/M00000545_FIT.sdf ../run_2.0/Gen084/M00000472_FIT.sdf ../run_2.0/Gen039/M00000228_FIT.sdf ../run_1.1/Final/M00000300_FIT.sdf ../run_2.0/Gen065/M00000386_FIT.sdf ../run_2.0/Gen053/M00000306_FIT.sdf ../run_2.0/Gen063/M00000370_FIT.sdf ../run_2.0/Gen035/M00000204_FIT.sdf ../run_2.0/Gen058/M00000346_FIT.sdf ../run_2.0/Gen056/M00000332_FIT.sdf ../run_1.1/Final/M00000297_FIT.sdf ../run_2.0/Gen061/M00000359_FIT.sdf ../run_2.0/Gen060/M00000357_FIT.sdf ../run_2.0/Gen051/M00000296_FIT.sdf ../run_1.1/Gen059/M00000381_FIT.sdf ../run_1.1/Gen046/M00000318_FIT.sdf ../run_2.0/Gen086/M00000487_FIT.sdf ../run_2.0/Gen059/M00000352_FIT.sdf ../run_2.0/Gen080/M00000445_FIT.sdf ../run_2.0/Gen091/M00000518_FIT.sdf ../run_2.0/Gen082/M00000462_FIT.sdf ../run_2.0/Gen067/M00000389_FIT.sdf ../run_2.0/Gen017/M00000115_FIT.sdf ../run_2.0/Gen080/M00000448_FIT.sdf ../run_2.0/Gen054/M00000318_FIT.sdf ../run_2.0/Gen035/M00000207_FIT.sdf ../run_2.0/Gen065/M00000384_FIT.sdf ../run_2.0/Gen059/M00000351_FIT.sdf ../run_2.0/Gen031/M00000182_FIT.sdf ../run_2.0/Gen057/M00000339_FIT.sdf ../run_2.0/Gen056/M00000337_FIT.sdf ../run_2.0/Gen069/M00000399_FIT.sdf ../run_2.0/Gen092/M00000521_FIT.sdf ../run_2.0/Gen059/M00000349_FIT.sdf ../run_2.0/Gen058/M00000343_FIT.sdf ../run_2.0/Gen042/M00000242_FIT.sdf ../run_2.0/Gen038/M00000221_FIT.sdf ../run_2.0/Gen061/M00000361_FIT.sdf ../run_1.1/Gen047/M00000320_FIT.sdf ../run_1.1/Final/M00000302_FIT.sdf ../run_2.0/Gen087/M00000488_FIT.sdf ../run_2.0/Gen073/M00000414_FIT.sdf ../run_1.1/Gen034/M00000254_FIT.sdf ../run_2.0/Gen034/M00000201_FIT.sdf ../run_1.1/Gen038/M00000274_FIT.sdf ../run_2.0/Gen096/M00000534_FIT.sdf ../run_2.0/Gen082/M00000458_FIT.sdf ../run_2.0/Gen081/M00000450_FIT.sdf ../run_2.0/Gen059/M00000348_FIT.sdf ../run_2.0/Gen043/M00000247_FIT.sdf ../run_2.0/Gen086/M00000485_FIT.sdf ../run_2.0/Gen032/M00000186_FIT.sdf ../run_2.0/Gen084/M00000474_FIT.sdf ../run_2.1/Gen048/M00000263_FIT.sdf ../run_2.0/Gen083/M00000463_FIT.sdf ../run_2.0/Gen073/M00000411_FIT.sdf ../run_2.0/Gen062/M00000368_FIT.sdf ../run_2.0/Gen051/M00000293_FIT.sdf ../run_2.0/Gen045/M00000261_FIT.sdf ../run_2.0/Gen032/M00000184_FIT.sdf ../run_2.0/Gen056/M00000335_FIT.sdf ../run_2.0/Gen012/M00000087_FIT.sdf ../run_2.0/Gen068/M00000395_FIT.sdf ../run_2.0/Gen033/M00000192_FIT.sdf ../run_1.1/Gen062/M00000401_FIT.sdf ../run_1.1/Gen051/M00000340_FIT.sdf ../run_1.1/Gen041/M00000289_FIT.sdf ../run_1.1/Final/M00000310_FIT.sdf ../run_2.0/Gen082/M00000455_FIT.sdf ../run_2.0/Gen026/M00000161_FIT.sdf ../run_1.1/Gen051/M00000341_FIT.sdf ../run_2.0/Gen014/M00000096_FIT.sdf ../run_1.1/Gen064/M00000406_FIT.sdf ../run_2.0/Gen015/M00000103_FIT.sdf ../run_2.0/Gen090/M00000509_FIT.sdf ../run_2.0/Gen081/M00000453_FIT.sdf ../run_2.0/Gen061/M00000363_FIT.sdf ../run_2.0/Gen023/M00000149_FIT.sdf ../run_2.0/Gen022/M00000142_FIT.sdf ../run_1.1/Gen040/M00000288_FIT.sdf ../run_2.0/Gen019/M00000130_FIT.sdf ../run_2.1/Gen055/M00000301_FIT.sdf ../run_2.1/Gen054/M00000298_FIT.sdf ../run_1.1/Gen055/M00000359_FIT.sdf ../run_1.1/Gen037/M00000267_FIT.sdf ../run_2.0/Gen037/M00000213_FIT.sdf ../run_2.0/Gen084/M00000470_FIT.sdf ../run_1.1/Gen063/M00000405_FIT.sdf ../run_2.0/Gen089/M00000503_FIT.sdf ../run_2.0/Gen087/M00000494_FIT.sdf ../run_2.0/Gen042/M00000244_FIT.sdf ../run_2.0/Gen024/M00000152_FIT.sdf ../run_2.2/Final/M00000174_FIT.sdf ../run_2.0/Gen092/M00000524_FIT.sdf ../run_1.1/Gen ...
